# %%
from LandsatL2C2 import LandsatL2C2
from sentinel import sentinel_tile_grid

# %%
tile = "11SPS"
geometry = sentinel_tile_grid.grid(tile, 30)
geometry
# Out:
# {
#   "dimensions": {
#     "rows": 3660,
#     "cols": 3660
#   },
#   "bbox": {
#     "xmin": 600000.0,
#     "ymin": 3590220.0,
#     "xmax": 709800.0,
#     "ymax": 3700020.0
#   },
#   "crs": "EPSG:32611",
#   "resolution": {
#     "cell_width": 30.0,
#     "cell_height": -30.0
#   }
# }

# %%
landsat = LandsatL2C2(working_directory="~/data/landsat_testing")
landsat
# Out:
# {
#   "host": "https://m2m.cr.usgs.gov/api/api/json/stable/",
#   "key": "eyJjaWQiOjEyODE0NjAsInMiOiIxNjY4ODAzMTA0IiwiciI6NzUxLCJwIjpbInVzZXIiLCJkb3dubG9hZCIsIm9yZGVyIl19",
#   "download_directory": "/Users/halverso/data/landsat_testing/landsat_download",
#   "products_directory": "/Users/halverso/data/landsat_testing/landsat_products",
#   "mosaic_directory": "/Users/halverso/data/landsat_testing/landsat_mosaic"
# }

# %%
# scenes = landsat.scene_search("2022-10-01", "2022-11-01", target_geometry=geometry)
# scenes

# %%
# scenes.date_UTC

# %%
ST_C = landsat.product("2022-11-01", "ST_C", geometry=geometry, target_name=tile)
ST_C
# Out:
# [2022-11-18 12:25:07 INFO] Landsat path/row tiles: 038.037, 038.038, 039.037
# [2022-11-18 12:25:07 INFO] searching dataset landsat_etm_c2_l2 tile 038.037 from 2022-11-01 to 2022-11-01
# [2022-11-18 12:25:08 INFO] found 0 scenes
# [2022-11-18 12:25:08 INFO] searching dataset landsat_etm_c2_l2 tile 038.038 from 2022-11-01 to 2022-11-01
# [2022-11-18 12:25:08 INFO] found 0 scenes
# [2022-11-18 12:25:08 INFO] searching dataset landsat_etm_c2_l2 tile 039.037 from 2022-11-01 to 2022-11-01
# [2022-11-18 12:25:09 INFO] found 0 scenes
# [2022-11-18 12:25:09 INFO] searching dataset landsat_ot_c2_l2 tile 038.037 from 2022-11-01 to 2022-11-01
# [2022-11-18 12:25:09 INFO] found 1 scenes
# [2022-11-18 12:25:09 INFO] searching dataset landsat_ot_c2_l2 tile 038.038 from 2022-11-01 to 2022-11-01
# [2022-11-18 12:25:10 INFO] found 1 scenes
# [2022-11-18 12:25:10 INFO] searching dataset landsat_ot_c2_l2 tile 039.037 from 2022-11-01 to 2022-11-01
# [2022-11-18 12:25:10 INFO] found 0 scenes
# [2022-11-18 12:25:10 INFO] retrieving whole Landsat L2 C2 granule: LC09_L2SP_038037_20221101_20221103_02_T1
# [2022-11-18 12:25:10 INFO] granule LC09_L2SP_038037_20221101_20221103_02_T1 already retrieved: /Users/halverso/data/landsat_testing/landsat_download/2022-11-01/LC09_L2SP_038037_20221101_20221103_02_T1
# [2022-11-18 12:25:10 INFO] processing ST_C for granule: LC09_L2SP_038037_20221101_20221103_02_T1
# [2022-11-18 12:25:12 INFO] retrieved ST_C 191289 pixels from LC09_L2SP_038037_20221101_20221103_02_T1
# [2022-11-18 12:25:12 INFO] retrieving whole Landsat L2 C2 granule: LC09_L2SP_038038_20221101_20221103_02_T1
# [2022-11-18 12:25:12 INFO] granule LC09_L2SP_038038_20221101_20221103_02_T1 already retrieved: /Users/halverso/data/landsat_testing/landsat_download/2022-11-01/LC09_L2SP_038038_20221101_20221103_02_T1
# [2022-11-18 12:25:12 INFO] processing ST_C for granule: LC09_L2SP_038038_20221101_20221103_02_T1
# [2022-11-18 12:25:13 INFO] retrieved ST_C 60821 pixels from LC09_L2SP_038038_20221101_20221103_02_T1
